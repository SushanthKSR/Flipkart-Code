# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# Install paddle OCR
# !pip install paddleocr
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from paddleocr import PaddleOCR, draw_ocr # main OCR dependencies
from matplotlib import pyplot as plt # plot images
import cv2 #opencv
import os # folder directory navigation

# %% [markdown]
# # 2. Instantiate Model and Detect

# %%
# Setup model
ocr_model = PaddleOCR(lang='en')
# Out:
# [2024/10/20 21:42:06] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/sushanthkesamreddy/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/sushanthkesamreddy/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', 
# ...

# %%
img_path = os.path.join('/Users/sushanthkesamreddy/Documents/ItemExpModel/Captured_Images/WhatsApp Image 2024-10-20 at 21.34.17.jpeg')

# %%
# Run the ocr method on the ocr model
result = ocr_model.ocr(img_path)
# Out:
# [2024/10/20 21:53:48] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/20 21:53:49] ppocr DEBUG: dt_boxes num : 82, elapsed : 0.7826519012451172
# [2024/10/20 21:53:56] ppocr DEBUG: rec_res num  : 82, elapsed : 6.823232889175415

# %%
result
# Out:
# [[[[[126.0, 227.0], [293.0, 223.0], [293.0, 253.0], [127.0, 257.0]],
#    ('CO INDIA HO', 0.8275098204612732)],
#   [[[375.0, 225.0], [523.0, 221.0], [524.0, 243.0], [375.0, 247.0]],
#    ('./1', 0.5129134654998779)],
#   [[[145.0, 252.0], [358.0, 250.0], [358.0, 278.0], [145.0, 280.0]],
#    ('7.DLF QUTAB ENCL', 0.894742488861084)],
#   [[[919.0, 283.0], [1020.0, 289.0], [1018.0, 327.0], [916.0, 321.0]],
#    ('OUR', 0.9851681590080261)],
#   [[[159.0, 334.0], [243.0, 324.0], [247.0, 354.0], [163.0, 364.0]],
#    ('USAT', 0.9894000291824341)],
#   [[[860.0, 374.0], [1025.0, 368.0], [1026.0, 396.0], [861.0, 402.0]],
#    ('The unmistaka', 0.9506415724754333)],
#   [[[833.0, 390.0], [1030.0, 397.0], [1029.0, 427.0], [831.0, 420.0]],
#    ("flavour of Lay's, co", 0.8746628761291504)],
#   [[[823.0, 411.0], [1032.0, 422.0], [1030.0, 455.0], [821.0, 445.0]],
#    ('&DELICIOUSLY se', 0.9542819857597351)],
#   [[[198.0, 445.0], [525.0, 445.0], [525.0, 468.0], [198.0, 468.0]],
# ...

# %%
for res in result:
    for line in res:  # Each line is a tuple (bounding box, text, confidence)
        text = line[1][0]  # Extract the detected text
        print(text)
# Out:
# CO INDIA HO
# ./1
# 7.DLF QUTAB ENCL
# OUR
# USAT
# The unmistaka
# flavour of Lay's, co
# &DELICIOUSLY se
# offer, valid in select geographies
# to PERFECTION
# Edible Vegetable Oil Palmolein
# Bursting with
# ning ~Spices &Condiments,
# flavourin
# every bite.
# SERVE SIZE 20 g**
# Orilgio
# ONALINFORMATION^
# quality pon
# Per100 g
# %RDA Per Serve
# becomely
# 531 kcal
# 5%
# Carefuly wie
# 6.69
# by our farmer
# experts for th
# 51.9g
# exceptional ton
# Maners
# andtexture.
# 1.6g
# Sugars
# 0.8g
# 0.3%
# sha
# 33 g
# 10%
# Mfg.&Mkt.by
# PepsiCo India Holdings vt.Ltd.
# Ceed Fat
# 14.7 g
# 13%
# fssai
# BFa
# 0.1g
# 1%
# Mkt.Lic.No.1001406400043
# 677 mg
# 7%
# upimate Values
# For Mkt.Addre can Barccse
# via Smart Consumer
# s e onion pack
# and see below:
# N1Lic.No.10012063000110
# N2Lic.No.10012022000339
# 1000120
# N3:Lic.No.
# ISALE PRICE:
# 950000033
# N4Lic.No.12
# FSERVES
# Rs.0.541-PERg
# For details on PepsiCo
# PACK B.NO.
# partnership with farmers,
# 1.4/N4100924
# ...
